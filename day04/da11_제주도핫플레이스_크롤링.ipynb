# %% [markdown]
# ## 빅데이터 실습
#
# ### 제주도 핫플레이스 웹크롤링
#
# ### 셀레니움 사용

# %%
# 셀레니움 및 필요 라이브러리사용등록
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import unicodedata #유니코드 데이터 처리 모듈
import re # 정규식 처리 모듈
import time

# %%
driver = webdriver.Chrome()

# %% [markdown]
# ##### 인스타그램 접속

# %%
# 인스타그램 접속
driver.get('https://www.instagram.com')
time.sleep(2.0)

# %% [markdown]
# ##### 자동 로그인 처리
# - 로그인 화면, 아이디, 패스워드 입력하는 html name 속성이 생김

# %%
# 인스타그램 사용자 이름(이메일)정보 입력
email = ''
input_id = driver.find_element(By.NAME, 'username')
input_id.clear()
input_id.send_keys(email)

# 인스타그램 비밀번호 입력
password = ''
input_pw = driver.find_element(By.NAME, 'password')
input_pw.clear()
input_pw.send_keys(password)
input_pw.submit()
time.sleep(2.0)

# %% [markdown]
# ##### 태그로 검색하면 30개 이상 검색안됨
# - 한 그룹의 게시물로 대체

# %%
## 검색결과 URL 함수
def searchInstagram(word):
    url = f'https://www.instagram.com/explore/tags/{word}'
    return url

# %%
## 24.03. 현재 태그로는 30개 이상 검색안됨
driver.get(searchInstagram('제주도맛집'))

# %%
##제주나드리 게시글로 검색
#https://www.instagram.com/jeju__nadri/
driver.get('https://www.instagram.com/jeju__nadri/')

# %% [markdown]
# ##### 게시글 클릭 후 게시글 정보 가져오기

# %%
# 첫번째 게시물 클릭
first = driver.find_element(By.CLASS_NAME,'_aagw')
first.click()
time.sleep(2.0)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 첫번째 게시물 클릭
# ----> 2 first = driver.find_element(By.CLASS_NAME,'_aagw')
#       3 first.click()
#       4 time.sleep(2.0)
#
# File c:\DEV\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\DEV\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File c:\DEV\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"._aagw"}
#   (Session info: chrome=122.0.6261.112); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF61106AD32+56930]
# 	(No symbol) [0x00007FF610FDF632]
# 	(No symbol) [0x00007FF610E942E5]
# 	(No symbol) [0x00007FF610ED98ED]
# 	(No symbol) [0x00007FF610ED9A2C]
# 	(No symbol) [0x00007FF610F1A967]
# 	(No symbol) [0x00007FF610EFBCDF]
# 	(No symbol) [0x00007FF610F181E2]
# 	(No symbol) [0x00007FF610EFBA43]
# 	(No symbol) [0x00007FF610ECD438]
# 	(No symbol) [0x00007FF610ECE4D1]
# 	GetHandleVerifier [0x00007FF6113E6ABD+3709933]
# 	GetHandleVerifier [0x00007FF61143FFFD+4075821]
# 	GetHandleVerifier [0x00007FF61143818F+4043455]
# 	GetHandleVerifier [0x00007FF611109766+706710]
# 	(No symbol) [0x00007FF610FEB90F]
# 	(No symbol) [0x00007FF610FE6AF4]
# 	(No symbol) [0x00007FF610FE6C4C]
# 	(No symbol) [0x00007FF610FD6904]
# 	BaseThreadInitThunk [0x00007FF8DA1E7344+20]
# 	RtlUserThreadStart [0x00007FF8DAE426B1+33]

# %%
## 게시글 정보 가져오기 함수
def getContent(driver):
    pass

# %%
## 게시글 가져오기 로직
## 1. html 코드 가져오기
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

## 2. 팝업 본문내용 가져오기
content = soup.select('div.x9f619')[0].text

firstIndex = str(soup.select('div.x9f619')[0]).index('>')
lastIndex = str(soup.select('div.x9f619')[0]).index('<br/>')
shopName = str(soup.select('div.x9f619')[0])[firstIndex+1:lastIndex]

## 3. 본문에서 해시태그 가져오기(정규식 활용)
tags = re.findall(r'#[^\s#,\\n]+',content)
tags

## 4. 포스트 작성일자
# date = soup.select('time.x1p4m5qa')[0]['datetime'][:10]
# date

## 5. 좋아요 수 가져오기
like = soup.select('span.xdj266r.x11i5rnm.xat24cr')[3].text
like

## 6. 위치정보
# re.findall(r'')
# Out:
# []

# %% [markdown]
# ##### 현재 문제
# - 인스타그램 화면 UI가 두 종류, 통일해서 코딩 불가

# %% [markdown]
# #### 워드 클라우드(Word Cloud)
# - 태그 중에서 빈도수가 높은 태그는 크게 글자를 크게, 빈도수가 낮은 태그는 작게 표현해서 마치 구름처럼 나타내는 방법

# %%
## 판다스등 필요 라이브러리 사용등록
import pandas as pd

# %%
raw_total = pd.read_excel('./data/1_crawling_raw.xlsx')
raw_total['tags']
# Out:
# 0       ['#제주핫플레이스', '#제주여행', '#제주여행', '#제주도여행', '#제주가...
# 1       ['#제주핫플', '#제주여행', '#제주', '#제주도', '#제주도맛집', '#...
# 2       ['#honestin', '#어니스틴', '#제주여행', '#제주', '#제주도',...
# 3       ['#제주관광', '#제주살이', '#제주이주민', '#아라동주민', '#삼남매집'...
# 4       ['#제주관광', '#제주', '#돔나이트', '#스트레스', '#풀자', '#춤추...
#                               ...
# 8796    ['#일상', '#구기자', '#티타임', '#2019', '#새해', '#차스타그...
# 8797    ['#제주', '#친정여행', '#겨울방학', '#제주여행앞머리는', '#친정찬스'...
# 8798                           ['#사진좀찍으시는님덕에건져또', '#이순간']
# 8799                                                   []
# 8800                            ['#HappyNewYearEveryone']
# Name: tags, Length: 8801, dtype: object

# %%
##
raw_total['tags'][0][2:-2].split("', '")[1]
# Out:
# '#제주여행'

# %%
from tqdm import tqdm

# %%
tagAllList = []

for tags in tqdm(raw_total['tags']): # 8800개 반복
    tagList = tags[2:-2].split("', '") # 다시 리스트로
    for tag in tagList: # 갯수가 유동
        tagAllList.append(tag)
# Out:
# 100%|██████████| 8801/8801 [00:00<00:00, 220170.88it/s]

# %%
tagAllList
# Out:
# ['#제주핫플레이스',
#  '#제주여행',
#  '#제주여행',
#  '#제주도여행',
#  '#제주가볼만한곳',
#  '#제주도핫플',
#  '#제주여행코스',
#  '#제주공항',
#  '#제주도맛집',
#  '#제주맛집',
#  '#제주스냅',
#  '#제주풍경',
#  '#제주사진',
#  '#제주카페',
#  '#제주도카페',
#  '#산굼부리',
#  '#제주도바다',
#  '#귤체험',
#  '#우도',
#  '#제주관광',
#  '#제주도여향지',
#  '#제주여행중',
#  '#삼육오빠',
#  '#제주앓이',
#  '#제주핫플',
#  '#제주여행',
#  '#제주',
#  '#제주도',
#  '#제주도맛집',
#  '#제주맛집',
#  '#여행',
#  '#제주맛집추천',
#  '#맛집추천',
#  '#제주공항',
#  '#제주카페',
#  '#제주디저트맛집',
#  '#제주데이트',
#  '#제주데이트코스',
#  '#제주도여행',
#  '#고집돌우럭',
#  '#중문맛집',
#  '#제주여행중',
#  '#감귤카페',
#  '#제주카페추천',
#  '#제주야시장',
#  '#맛집',
#  '#제주갈만한곳',
#  '#제주관광',
#  '#좋아요반사',
#  '#좋반',
#  '#제주도여행지',
#  '#제주도가볼만한곳',
#  '#제주여행코스',
#  '#honestin',
#  '#어니스틴',
#  '#제주여행',
#  '#제주',
#  '#제주도',
#  '#제주도여행',
#  '#제주살이',
#  '#제주도민',
#  '#제주가볼만한곳',
#  '#제주일상',
#  '#제주도가볼만한곳',
#  '#제주핫플레이스',
#  '#제주핫플',
#  '#제주라이프',
#  '#가을제주',
#  '#제주시',
#  '#제주여행코스',
#  '#제주도핫플',
#  '#제주오름',
#  '#들렁모루',
#  '#비밀의정원',
#  '#삼굼부리',
#  '#정물오름',
#  '#자연생태마을',
#  '#오조포구',
#  '#올레길',
#  '#제주하늘',
#  '#제주관광',
#  '#11월여행',
#  '#제주관광',
#  '#제주살이',
#  '#제주이주민',
#  '#아라동주민',
#  '#삼남매집',
#  '#새해첫날',
#  '#드라이브',
#  '#명월국민학교',
#  '#낙서',
#  '#잡히면죽는다',
#  '#제주관광',
#  '#제주',
#  '#돔나이트',
#  '#스트레스',
#  '#풀자',
#  '#춤추며',
#  '#땀날려',
#  '#가끔은괜찮아',
#  '#인생',
#  '#즐기며',
#  '#놀자',
#  '#제주에인감귤밭',
#  '#감귤체험',
#  '#귤따기체험',
#  '#체험농장',
#  '#감귤따기체험',
#  '#감귤밭',
#  '#감귤밭카페',
#  '#제주감성',
#  '#제주여행',
#  '#제주관광',
#  '#제주카페',
#  '#제주카페추천',
#  '#서귀포카페',
#  '#서귀포카페추천',
#  '#제주선물',
#  '#제주선물추천',
#  '#감귤잼',
#  '#한라봉청',
#  '#청귤청',
#  '#금귤청',
#  '#제주여행',
#  '#제주관광',
#  '#노리매공원',
#  '#카멜리아힐',
#  '#핑크뮬리',
#  '#제주가볼만한곳',
#  '#제주사진찍기좋은곳',
#  '#에인감귤밭',
#  '#제주에인감귤밭',
#  '#제주에인감귤밭',
#  '#감귤체험',
#  '#귤따기체험',
#  '#체험농장',
#  '#감귤따기체험',
#  '#감귤밭',
#  '#감귤밭카페',
#  '#제주감성',
#  '#제주여행',
#  '#제주관광',
#  '#제주카페',
#  '#제주카페추천',
#  '#서귀포카페',
#  '#서귀포카페추천',
#  '#제주선물',
#  '#제주선물추천',
#  '#감귤잼',
#  '#한라봉청',
#  '#청귤청',
#  '#금귤청',
#  '#제주여행',
#  '#제주관광',
#  '#노리매공원',
#  '#카멜리아힐',
#  '#핑크뮬리',
#  '#제주가볼만한곳',
#  '#제주사진찍기좋은곳',
#  '#에인감귤밭',
#  '#제주에인감귤밭',
#  '#niceweather',
#  '#winterswimming',
#  '#제주',
#  '#바다수영',
#  '#겨울수영',
#  '#가을수영',
#  '#개헤엄',
#  '#제주도',
#  '#jejudo',
#  '#jeju',
#  '#jejuisland',
#  '#제주스냅',
#  '#제주관광',
#  '#제주여행',
#  '#석양',
#  '#sunset',
#  '#sunrise',
#  '#horizon',
#  '#yolo',
#  '#소확행',
#  '#lighthouse',
#  '#제주버스여행',
#  '#제주도여행',
#  '#제주살이',
#  '#제주오름',
#  '#제주올레길',
#  '#한라산둘레길',
#  '#올레길',
#  '#제주에서한복입고여행하기',
#  '#한복입는선흘집',
#  '#파스텔제주',
#  '#레드향',
#  '#천혜향',
#  '#한라봉',
#  '#귤오름농원',
#  '#귤농장',
#  '#과수원',
#  '#터가좋다고유명한곳',
#  '#겨울제주',
#  '#제주관광',
#  '#게스트하우스',
#  '#제주여행',
#  '#건강',
#  '#비타민',
#  '#영양제',
#  '#천연비타민',
#  '#제철과일',
#  '#jmt',
#  '#jmtgr',
#  '#새해',
#  '#사랑',
#  '#존경',
#  '#고마움',
#  '#배려',
#  '#선물',
#  '#기해년',
#  '#희망',
#  '#꿈',
#  '#황금돼지',
#  '#2019',
#  '#새해선물',
#  '#두피반영구',
#  '#셀카',
#  '#선팔',
#  '#제주눈썹예쁜곳',
#  '#제주속눈썹연장',
#  '#붙임머리',
#  '#첫줄',
#  '#서귀포남자눈썹문신',
#  '#제주해안도로',
#  '#서귀포자연눈썹',
#  '#제주국제대',
#  '#제주남자눈썹문신',
#  '#제주자연눈썹',
#  '#제주메이크업',
#  '#서귀포속눈썹',
#  '#제주육아',
#  '#제주속눈썹',
#  '#서귀포반영구',
#  '#제주시',
#  '#서귀포눈썹문신',
#  '#제주맘',
#  '#제주반영구',
#  '#서귀포',
#  '#제주눈썹문신',
#  '#반영구',
#  '#제주관광',
#  '#눈썹문신',
#  '#서귀포맘',
#  '#제주맛집',
#  '#제주관광',
#  '#제주볼거리',
#  '#무료입장',
#  '#제주먹거리',
#  '#캔디원',
#  '#아이들과',
#  '#수제캔디',
#  '#수제젤리',
#  '#수제사탕',
#  '#디저트',
#  '#기분전환',
#  '#당떨어질때',
#  '#제주',
#  '#만장굴',
#  '#동굴',
#  '#제주관광',
#  '#무셔',
#  '#여행',
#  '#여행스타그램',
#  '#제주관광',
#  '#제주살이',
#  '#제주이주민',
#  '#아라동주민',
#  '#삼남매집',
#  '#이시돌목장',
#  '#테쉬폰',
#  '#우유부단',
#  '#제주남자눈썹문신',
#  '#제주자연눈썹',
#  '#서귀포자연눈썹',
#  '#서귀포남자눈썹문신',
#  '#서귀포속눈썹',
#  '#붙임머리',
#  '#제주속눈썹연장',
#  '#제주속눈썹',
#  '#제주문신',
#  '#제주두피반영구',
#  '#서귀포반영구',
#  '#서귀포문신',
#  '#제주도맛집',
#  '#서귀포눈썹문신',
#  '#제주반영구수강',
#  '#제주반영구',
#  '#제주도관광',
#  '#서귀포맛집',
#  '#제주눈썹문신',
#  '#서귀포반영구수강',
#  '#제주맛집',
#  '#반영구',
#  '#제주관광',
#  '#서귀포속눈썹파마',
#  '#눈썹문신',
#  '#서귀포',
#  '#제주속눈썹파마',
#  '#제주시',
#  '#제주메이크업',
#  '#여자눈썹',
#  '#남자눈썹',
#  '#제주해안도로',
#  '#제주속눈썹연장',
#  '#제주메이크업',
#  '#서귀포남자눈썹문신',
#  '#첫줄',
#  '#서귀포자연눈썹',
#  '#제주시',
#  '#제주남자눈썹문신',
#  '#셀카',
#  '#제주자연눈썹',
#  '#서귀포',
#  '#서귀포속눈썹',
#  '#선팔',
#  '#제주속눈썹',
#  '#제주관광',
#  '#서귀포반영구',
#  '#두피반영구',
#  '#서귀포눈썹문신',
#  '#제주맛집',
#  '#제주반영구',
#  '#제주눈썹예쁜곳',
#  '#제주눈썹문신',
#  '#서귀포맛집',
#  '#반영구',
#  '#제주국제대',
#  '#눈썹문신',
#  '#제주도관광',
#  '#제주도맛집',
#  '#애월카페',
#  '#제주리치망고',
#  '#도두리치망고',
#  '#제주관광',
#  '#제주반영구',
#  '#제주여자눈썹',
#  '#데일리화장',
#  '#수지눈썹',
#  '#아이라인',
#  '#제주시속눈썹펌',
#  '#뷰러펌',
#  '#제주시네일',
#  '#제주속눈썹펌잘하는곳',
#  '#남자눈썹',
#  '#제주남자눈썹잘하는곳',
#  '#연예인눈썹',
#  '#서귀포',
#  '#서귀포맛집',
#  '#제주대학생',
#  '#얼스타그램',
#  '#제주도민',
#  '#permanentmakeup',
#  '#eyeline',
#  '#자연눈썹',
#  '#안개눈썹',
#  '#서귀포눈썹문신',
#  '#eyelash',
#  '#eyebrowstattoo',
#  '#제주관광',
#  '#제주메이크업',
#  '#제주눈썹문신',
#  '#제주반영구',
#  '#제주여자눈썹',
#  '#데일리화장',
#  '#수지눈썹',
#  '#아이라인',
#  '#제주시속눈썹펌',
#  '#뷰러펌',
#  '#제주시네일',
#  '#제주속눈썹펌잘하는곳',
#  '#남자눈썹',
#  '#제주남자눈썹잘하는곳',
#  '#연예인눈썹',
#  '#서귀포',
#  '#서귀포맛집',
#  '#제주대학생',
#  '#얼스타그램',
#  '#제주도민',
#  '#permanentmakeup',
#  '#eyeline',
#  '#자연눈썹',
#  '#안개눈썹',
#  '#서귀포눈썹문신',
#  '#제주관광',
#  '#제주메이크업',
#  '#제주눈썹문신',
#  '#광양반영구',
#  '#광양눈썹문신',
#  '#순천반영구',
#  '#순천눈썹문신',
#  '#순천반영구출장',
#  '#제주자연눈썹',
#  '#서귀포속눈썹',
#  '#제주남자눈썹문신',
#  '#서귀포자연눈썹',
#  '#제주속눈썹',
#  '#서귀포남자눈썹문신',
#  '#붙임머리',
#  '#서귀포반영구',
#  '#제주속눈썹연장',
#  '#제주반영구수강',
#  '#서귀포반영구수강',
#  '#서귀포눈썹문신',
#  '#제주두피반영구',
#  '#제주문신',
#  '#제주반영구',
#  '#서귀포속눈썹파마',
#  '#서귀포문신',
#  '#제주눈썹문신',
#  '#제주도맛집',
#  '#제주속눈썹파마',
#  '#반영구',
#  '#제주도관광',
#  '#서귀포맛집',
#  '#눈썹문신',
#  '#제주여자눈썹',
#  '#제주맛집',
#  '#제주관광',
#  '#제주남자눈썹',
#  '#서귀포',
#  '#첫줄',
#  '#제주해안도로',
#  '#제주속눈썹연장',
#  '#셀카',
#  '#붙임머리',
#  '#서귀포남자눈썹문신',
#  '#제주메이크업',
#  '#서귀포자연눈썹',
#  '#선팔',
#  '#제주남자눈썹문신',
#  '#제주시',
#  '#제주자연눈썹',
#  '#두피반영구',
#  '#서귀포속눈썹',
#  '#서귀포',
#  '#제주속눈썹',
#  '#제주눈썹예쁜곳',
#  '#서귀포반영구',
#  '#서귀포눈썹문신',
#  '#제주관광',
#  '#제주반영구',
#  '#제주국제대',
#  '#제주눈썹문신',
#  '#제주맛집',
#  '#반영구',
#  '#서귀포맛집',
#  '#눈썹문신',
#  '#제주육아',
#  '#제주도관광',
#  '#서귀포자연눈썹',
#  '#서귀포남자눈썹문신',
#  '#제주남자눈썹문신',
#  '#붙임머리',
#  '#제주속눈썹연장',
#  '#제주자연눈썹',
#  '#제주도관광',
#  '#서귀포속눈썹',
#  '#제주도맛집',
#  '#서귀포맛집',
#  '#제주속눈썹',
#  '#서귀포문신',
#  '#서귀포반영구',
#  '#제주맛집',
#  '#제주관광',
#  '#서귀포눈썹문신',
#  '#제주문신',
#  '#제주반영구',
#  '#서귀포',
#  '#제주두피반영구',
#  '#제주눈썹문신',
#  '#제주시',
#  '#반영구',
#  '#제주메이크업',
#  '#제주반영구수강',
#  '#눈썹문신',
#  '#제주해안도로',
#  '#서귀포반영구수강',
#  '#첫줄',
#  '#제주여행',
#  '#제주관광',
#  '#제주감귤',
#  '#한라봉',
#  '#레드향',
#  '#천혜향',
#  '#제주맛집',
#  '#전국택배',
#  '#과일청',
#  '#과일주스',
#  '#과일칩',
#  '#제주카페',
#  '#딸부자',
#  '#배달가능',
#  '#각종과일',
#  '#제주눈썹예쁜곳',
#  '#선팔',
#  '#두피반영구',
#  '#셀카',
#  '#제주속눈썹연장',
#  '#제주국제대',
#  '#붙임머리',
#  '#첫줄',
#  '#서귀포남자눈썹문신',
#  '#서귀포자연눈썹',
#  '#제주해안도로',
#  '#제주남자눈썹문신',
#  '#제주육아',
#  '#제주자연눈썹',
#  '#서귀포속눈썹',
#  '#제주메이크업',
#  '#제주속눈썹',
#  '#제주맘',
#  '#서귀포반영구',
#  '#서귀포눈썹문신',
#  '#제주시',
#  '#제주반영구',
#  '#서귀포',
#  '#제주눈썹문신',
#  '#반영구',
#  '#서귀포맘',
#  '#눈썹문신',
#  '#제주관광',
#  '#제주대학생',
#  '#한라산',
#  '#1100고지.너무',
#  '#아들',
#  '#겨울제주',
#  '#눈',
#  '#제주도민',
#  '#제주도',
#  '#일상',
#  '#제주',
#  '#제주여행',
#  '#제주관광',
#  '#제주',
#  '#제주도',
#  '#제주여행',
#  '#제주관광',
#  '#제주카트',
#  '#국내최대규모',
#  '#제주레포츠랜드',
#  '#국내최대규모카트장',
#  '#산악버기카',
#  '#짚라인',
#  '#사계절썰매장',
#  '#페인트사격',
#  '#서바이벌',
#  '#핫플레이스',
#  '#jeju',
#  '#가볼만한곳',
#  '#한라산',
#  '#주상절리',
#  '#용머리해안',
#  '#산방산',
#  '#에코랜드',
#  '#절물자연휴양림',
#  '#산굼부리',
#  '#산도위치',
#  '#육떡식당',
#  '#청춘여관',
#  '#청춘회관',
#  '#너도나도ATV',
#  '#2019년',
#  '#새해',
#  '#제주오름마당',
#  '#제주도',
#  '#제주관광',
#  '#제주여행',
#  '#2019',
#  '#Jeju',
#  '#Jejudo',
#  '#Jeju',
#  '#서귀포자연눈썹',
#  '#제주남자눈썹문신',
#  '#서귀포남자눈썹문신',
#  '#붙임머리',
#  '#제주자연눈썹',
#  '#제주속눈썹연장',
#  '#서귀포속눈썹',
#  '#제주도맛집',
#  '#서귀포문신',
#  '#제주속눈썹',
#  '#제주도관광',
#  '#서귀포반영구',
#  '#서귀포맛집',
#  '#제주문신',
#  '#서귀포눈썹문신',
#  '#제주맛집',
#  '#제주두피반영구',
#  '#제주반영구',
#  '#제주관광',
#  '#제주눈썹문신',
#  '#서귀포',
#  '#제주반영구수강',
#  '#반영구',
#  '#제주시',
#  '#눈썹문신',
#  '#서귀포반영구수강',
#  '#제주메이크업',
#  '#제주해안도로',
#  '#서귀포속눈썹파마',
#  '#제주',
#  '#jejudo',
#  '#jeju',
#  '#jejuisland',
#  '#제주관광',
#  '#제주여행',
#  '#한라산',
#  '#일출',
#  '#노을',
#  '#sunset',
#  '#sunrise',
#  '#yolo',
#  '#소확행',
#  '#lighthouse',
#  '#제주버스여행',
#  '#제주도여행',
#  '#제주살이',
#  '#제주오름',
#  '#제주올레길',
#  '#한라산둘레길',
#  '#올레길',
#  '#제주펜션',
#  '#제주펜션추천',
#  '#제주펜션예약',
#  '#제주숙소',
#  '#제주관광',
#  '#제주여행',
#  '#데이트',
#  '#제주커플펜션',
#  '#사랑',
#  '#일상',
#  '#겨울',
#  '#춥다',
#  '#폴딩도어',
#  '#데크',
#  '#제주눈',
#  '#제주펜션',
#  '#제주펜션추천',
#  '#제주펜션예약',
#  '#제주숙소',
#  '#제주관광',
#  '#제주여행',
#  '#데이트',
#  '#제주커플펜션',
#  '#사랑',
#  '#일상',
#  '#최선',
#  '#2019년',
#  '#새해맞이',
#  '#제주겨울여행',
#  '#정글북바이앨리스',
#  '#카운트다운',
#  '#행사',
#  '#성공',
#  '#새해',
#  '#소망',
#  '#풍선',
#  '#제주핫플',
#  '#제주술집',
#  '#신제주술집',
#  '#노형술집',
#  '#제원맛집',
#  '#제원술집',
#  '#제주맛집',
#  '#제주도민',
#  '#제주여행',
#  '#제주',
#  '#메종글래드제주',
#  '#제주혼자여행',
#  '#제주바',
#  '#제주살이',
#  '#제주와인',
#  '#제주와인바',
#  '#제주관광',
#  '#제주일상',
#  '#제주칵테일',
#  '#제주칵테일바',
#  '#제주라운지바',
#  '#정글북',
#  '',
#  '#정글북바이앨리스',
#  '#카운트다운',
#  '#행사',
#  '#성공',
#  '#새해',
#  '#소망',
#  '#풍선',
#  '#제주핫플',
#  '#제주술집',
#  '#노형술집',
#  '#제원',
#  '#제원맛집',
#  '#제원술집',
#  '#제주맛집',
#  '#노형',
#  '#제주도민',
#  '#제주여행',
#  '#제주',
#  '#메종글래드제주',
#  '#제주혼자여행',
#  '#제주바',
#  '#제주살이',
#  '#제주와인',
#  '#제주와인바',
#  '#제주관광',
#  '#제주일상',
#  '#제주칵테일',
#  '#제주칵테일바',
#  '#제주라운지바',
#  '#정글북',
#  '',
#  '#제주도풍경',
#  '#거문오름',
#  '#드로잉',
#  '#제주여행',
#  '#drawing',
#  '#제주세계자연유산센터',
#  '#uskjeju',
#  '#urbansketchersjeju',
#  '#여행드로잉',
#  '#제주',
#  '#연필드로잉',
#  '#staedtler',
#  '#여행과그림...',
#  '#제주시',
#  '#여행드로잉',
#  '#자연유산',
#  '#그림여행',
#  '#travel_artist',
#  '#제주도',
#  '#오름여행',
#  '#제주관광',
#  '#traveldrawing',
#  '#연필',
#  '#스테들러',
#  '#어반스케쳐',
#  '#여행',
#  '#풍경드로잉',
#  '#어반스케쳐스제주',
#  '#제주시관광',
#  '#제주',
#  '#제주하늘',
#  '#새해',
#  '#첫해',
#  '#새해첫해님',
#  '#1월1일',
#  '#제주하늘위해님',
#  '#제주여행',
#  '#제주관광',
#  '#가족여행',
#  '#에어부산',
#  '#여행스타그램✈️',
#  '#어린이놀이터',
#  '#김녕미로공원',
#  '#제주여행',
#  '#미로공원',
#  '#제주미로공원',
#  '#jejuisland',
#  '#만장굴',
#  '#여행스타그램',
#  '#여행',
#  '#여행에미치다',
#  '#아이와제주여행',
#  '#아이와가볼만한곳',
#  '#아이와함께',
#  '#아이와여행',
#  '#제주추천',
#  '#제주카페',
#  '#제주관광',
#  '#제주관광지',
#  '#아이와가볼만한곳',
#  '#아이와제주',
#  '#제주도아이와가볼만한곳',
#  '#제주아이와갈만한곳',
#  '#제주키즈카페',
#  '#제주도여행코스',
#  '#제주여행코스',
#  '#제주관광',
#  '#서귀포맛집',
#  '#~~새록새록',
#  '#새해복많이',
#  '#꾸까카페',
#  '#제주카페',
#  '#카페꾸까',
#  '#건입동카페',
#  '#사라봉카페',
#  '#플라워카페',
#  '#제이플로라',
#  '#제주플라워샵',
#  '#빙수맛집',
#  '#씨앗호떡',
#  '#호떡맛집',
#  '#꿀호떡',
#  '#수제얼음',
#  '#댕유자빙수',
#  '#커피맛집',
#  '#제주카페추천',
#  '#카페추천',
#  '#캘리홀더',
#  '#캘리스타그램',
#  '#소통',
#  '#선팔',
#  '#맞팔',
#  '#꽃카페',
#  '#꽃다방',
#  '#제주국립박물관',
#  '#제주여행',
#  '#제주관광',
#  '#여행스타그램',
#  '#제주스타그램',
#  '#서귀포남자눈썹문신',
#  '#붙임머리',
#  '#서귀포자연눈썹',
#  '#제주속눈썹연장',
#  '#제주남자눈썹문신',
#  '#제주맛집',
#  '#서귀포맛집',
#  '#제주자연눈썹',
#  '#제주관광',
#  '#서귀포속눈썹',
#  '#제주도관광',
#  '#제주속눈썹',
#  '#서귀포',
#  '#서귀포반영구',
#  '#제주시',
#  '#제주도맛집',
#  '#서귀포눈썹문신',
#  '#제주메이크업',
#  '#제주반영구',
#  '#서귀포문신',
#  '#제주눈썹문신',
#  '#제주해안도로',
#  '#제주문신',
#  '#반영구',
#  '#첫줄',
#  '#눈썹문신',
#  '#제주두피반영구',
#  '#셀카',
#  '#선팔',
#  '#제주',
#  '#제주공항',
#  '#제주공항국내선',
#  '#에어부산',
#  '#집으로가는길',
#  '#제주여행',
#  '#제주관광',
#  '#여행스타그램✈️',
#  '#제주',
#  '#제주도',
#  '#제주살이',
#  '#제주도민',
#  '#재활',
#  '#통증',
#  '#두통',
#  '#허리통증',
#  '#어깨통증',
#  '#제주마사지',
#  '#제주마사지샵',
#  '#제주시마사지',
#  '#효도',
#  '#제주여행',
#  '#제주관광',
#  '#pt',
#  '#일상',
#  '#소통',
#  '#2019',
#  '#새해',
#  '#new',
#  '#happy',
#  '#시작',
#  '',
#  '#제주',
#  '#제주용담동',
#  '#생선회',
#  '#방어뱃살회',
#  '#참돔회',
#  '#딱새우회',
#  '#제주올레소주',
#  '#설중매스파클링',
#  '#저녁',
#  '#제주여행',
#  '#제주관광',
#  '#가족여행',
#  '#먹스타그램🍴',
#  '#여행스타그램✈️',
#  '#제주',
#  '#제주용담동',
#  '#제주몽듀호텔',
#  '#오션뷰호털',
#  '#제주숙소',
#  '#제주관광',
#  '#제주여행',
#  '#가족여행',
#  '#여행스타그램✈️',
#  '#제주',
#  '#제주용담동',
#  '#제주스타벅스',
#  '#스타벅스',
#  '#제주한라봉라떼',
#  '#제주까망라떼',
#  '#제주스타벅스음료',
#  '#스타벅스용담DT점',
#  '#디저트',
#  '#제주여행',
#  '#제주관광',
#  '#가족여행',
#  '#먹스타그램🍴',
#  '#여행스타그램✈️',
#  '#제주해안도로',
#  '#제주속눈썹연장',
#  '#제주메이크업',
#  '#붙임머리',
#  '#첫줄',
#  '#서귀포남자눈썹문신',
#  '#서귀포자연눈썹',
#  '#제주시',
#  '#제주남자눈썹문신',
#  '#셀카',
#  '#제주자연눈썹',
#  '#서귀포',
#  '#서귀포속눈썹',
#  '#선팔',
#  '#제주속눈썹',
#  '#제주관광',
#  '#서귀포반영구',
#  '#두피반영구',
#  '#서귀포눈썹문신',
#  '#제주맛집',
#  '#제주반영구',
#  '#제주눈썹예쁜곳',
#  '#제주눈썹문신',
#  '#서귀포맛집',
#  '#반영구',
#  '#제주도관광',
#  '#눈썹문신',
#  '#제주국제대',
#  '#제주도맛집',
#  '#서귀포자연눈썹',
#  '#제주남자눈썹문신',
#  '#서귀포남자눈썹문신',
#  '#제주속눈썹연장',
#  '#제주자연눈썹',
#  '#남자눈썹',
#  '#서귀포속눈썹',
#  '#여자눈썹',
#  '#제주도맛집',
#  '#제주속눈썹',
#  '#제주도관광',
#  '#서귀포문신',
#  '#서귀포반영구',
#  '#서귀포맛집',
#  '#서귀포눈썹문신',
#  '#제주맛집',
#  '#제주문신',
#  '#제주반영구',
#  '#제주관광',
#  '#제주두피반영구',
#  '#제주눈썹문신',
#  '#서귀포',
#  '#반영구',
#  '#제주시',
#  '#제주반영구수강',
#  '#눈썹문신',
#  '#제주메이크업',
#  '#제주해안도로',
#  '#서귀포반영구수강',
#  '#1다가오는',
#  '#22018년도',
#  '#3올해',
#  '#4다시',
#  '#5모든분들과',
#  '#제주꿈꾸는고래',
#  '#제주스쿠버다이빙',
#  '#제주게스트하우스',
#  '#제주스킨스쿠버',
#  '#서귀포보트다이빙',
#  '#제주프리다이빙',
#  '#제주체험다이빙',
#  '#제주스노클링',
#  '#제주스쿠버다이빙교육',
#  '#제주스킨스쿠버교육',
#  '#서귀포지깅낚시_타이라바낚시',
#  '#제주여성전용게스트하우스',
#  '#제주관광',
#  '#서귀포게스트하우스',
#  '#제주바다여행',
#  '#꿈꾸는고래',
#  '#플레이케이팝남편님',
#  '#중문관광단지',
#  '#플레이케이팝박물관',
#  '#제주여행',
#  '#가족여행',
#  '#여행',
#  ...]

# %%
## 해시태그 출현 빈도
from collections import Counter

# %%
tagCounts = Counter(tagAllList)

# %%
tagCounts.most_common(50)
# Out:
# [('#제주맛집', 3750),
#  ('#제주도맛집', 3467),
#  ('#제주여행', 3204),
#  ('#제주관광', 2898),
#  ('#제주도', 2096),
#  ('#제주', 1567),
#  ('#제주도여행', 1555),
#  ('#서귀포맛집', 1392),
#  ('#제주도가볼만한곳', 1047),
#  ('#서귀포', 872),
#  ('#제주핫플레이스', 848),
#  ('#jeju', 776),
#  ('#제주흑돼지맛집', 730),
#  ('#제주맛집추천', 728),
#  ('#일상', 717),
#  ('#제주도흑돼지', 713),
#  ('#제주카페', 711),
#  ('#제주도흑돼지맛집', 709),
#  ('#제주흑돼지', 693),
#  ('#협재맛집', 677),
#  ('#성산일출봉', 674),
#  ('#제주도민', 637),
#  ('#제주도그램', 609),
#  ('#서귀포흑돼지맛집', 605),
#  ('', 588),
#  ('#서귀포흑돼지', 582),
#  ('#제주가볼만한곳', 580),
#  ('#성산일출봉맛집', 567),
#  ('#섭지코지', 558),
#  ('#제주도민맛집', 542),
#  ('#제주핫플', 530),
#  ('#선팔', 522),
#  ('#섭지코지맛집', 519),
#  ('#제주살이', 516),
#  ('#여행스타그램', 498),
#  ('#통갈치구이', 495),
#  ('#제주통갈치구이', 485),
#  ('#제주서귀포맛집', 479),
#  ('#제주반영구', 478),
#  ('#중문맛집', 472),
#  ('#제주눈썹문신', 472),
#  ('#제주도관광', 471),
#  ('#서귀포눈썹문신', 458),
#  ('#여행', 455),
#  ('#먹스타그램', 453),
#  ('#제주시', 451),
#  ('#반영구', 443),
#  ('#눈썹문신', 443),
#  ('#제주자연눈썹', 435),
#  ('#제주속눈썹', 435)]

# %%
## 막잡 이외의 해시태그는 제외, 워드클라우드 결과보고 다시 필요없는 해시태그 추가, 정제한뒤
STOPWORDS = ['#제주도', '#제주', '#jeju', '#제주시', '#일상', '#제주도민', '#반영구', '#눈썹문신', 
            '#제주자연눈썹', '#제주속눈썹', '', '#서귀포', '#제주도그램', '#선팔', '#제주살이', '#여행스타그램',
            '#제주반영구', '#제주눈썹문신', '#서귀포눈썹문신', '#서귀포남자눈썹문신', '#서귀포자연눈썹',
            '#제주남자눈썹문신', '#서귀포속눈썹', '#서귀포반영구', '#제주스타그램', '#소통', '#맞팔', '#제주메이크업',
            '#daily', '#가족여행', '#jejuisland', '#제주속눈썹연장', '#제주해안도로', '#셀카', '#제주공항',
            '#서귀포문신', '#데일리', '#제주문신']

tagFilterList = []
for tag in tagAllList:
    if tag not in STOPWORDS: # 제외시킬 단어에 속하지 않으면
        tagFilterList.append(tag)

# %%
tagFilterCounts = Counter(tagFilterList)
tagFilterCounts.most_common(50)
# Out:
# [('#제주맛집', 3750),
#  ('#제주도맛집', 3467),
#  ('#제주여행', 3204),
#  ('#제주관광', 2898),
#  ('#제주도여행', 1555),
#  ('#서귀포맛집', 1392),
#  ('#제주도가볼만한곳', 1047),
#  ('#제주핫플레이스', 848),
#  ('#제주흑돼지맛집', 730),
#  ('#제주맛집추천', 728),
#  ('#제주도흑돼지', 713),
#  ('#제주카페', 711),
#  ('#제주도흑돼지맛집', 709),
#  ('#제주흑돼지', 693),
#  ('#협재맛집', 677),
#  ('#성산일출봉', 674),
#  ('#서귀포흑돼지맛집', 605),
#  ('#서귀포흑돼지', 582),
#  ('#제주가볼만한곳', 580),
#  ('#성산일출봉맛집', 567),
#  ('#섭지코지', 558),
#  ('#제주도민맛집', 542),
#  ('#제주핫플', 530),
#  ('#섭지코지맛집', 519),
#  ('#통갈치구이', 495),
#  ('#제주통갈치구이', 485),
#  ('#제주서귀포맛집', 479),
#  ('#중문맛집', 472),
#  ('#제주도관광', 471),
#  ('#여행', 455),
#  ('#먹스타그램', 453),
#  ('#제주일상', 424),
#  ('#애월맛집', 410),
#  ('#제주시맛집', 387),
#  ('#카멜리아힐', 384),
#  ('#중문흑돼지맛집', 377),
#  ('#제주도여행코스', 361),
#  ('#제주도카페', 354),
#  ('#성산맛집', 342),
#  ('#좋아요', 318),
#  ('#서귀포맛집추천', 315),
#  ('#첫줄', 311),
#  ('#한림맛집', 308),
#  ('#제주공항근처맛집', 307),
#  ('#제주공항맛집', 275),
#  ('#오설록', 247),
#  ('#제주도맛집추천', 246),
#  ('#제주도이색맛집', 240),
#  ('#서귀포여행', 238),
#  ('#서귀포카페', 233)]

# %%
##### 시각화 라이브러리 사용등록
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 한글 깨짐 문제 해결
from matplotlib import rcParams, font_manager,rc

font_path = 'C:/windows/Fonts/NanumGothicCoding.ttf'#나눔고딕체 사용
font = font_manager.FontProperties(fname=font_path).get_name() #실제 설치된 폰트 이름조회
rc('font', family=font) #한글깨짐현상 해결!!
rcParams['axes.unicode_minus']=False #한글 사용시 마이너스 표시 깨짐 해결!

# %%
# 차트 스타일 지정
sns.set_style('darkgrid')

# %%
dfTagCounts = pd.DataFrame(tagFilterCounts.most_common(30))

# %%
dfTagCounts.columns = ['tag', 'counts']

# %%
## 불필요한 경고 메시지 제거
import warnings
warnings.filterwarnings('ignore')

# %%
## 막대차트
plt.figure(figsize=(10,10))
##palette 종류 : pastel, husl, hls, Set2, Paired, rocket, rocket_r, mako
sns.barplot(x='counts', y='tag', data=dfTagCounts, palette='husl')
plt.show()

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\dev\python312\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\dev\python312\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\dev\python312\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\dev\python312\lib\site-packages (from wordcloud) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\python312\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\dev\python312\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\python312\lib\site-packages (from matplotlib->wordcloud) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dev\python312\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\dev\python312\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\python312\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\dev\python312\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\dev\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# 워드 클라우드 라이브러리 사용등록
from wordcloud import WordCloud

# %%
import platform

if platform.system() =='Windows':
    fontPath = 'C:/Windows/Fonts/NanumGothic.ttf'
elif platform.system() == 'Darwin': #macos
    fontPath = '/Users/$USER/Library/Fonts/AppleGothic.ttf'

# %%
sns.set_style('white')

# %%
#워드 클라우드 만들기
tagsLast = dict(tagFilterCounts.most_common(50))
wc= WordCloud(font_path=fontPath, colormap='inferno',
              relative_scaling=0.4, width=1000, height=600,
              background_color='white', max_words=100).generate_from_frequencies(tagsLast)
plt.figure(figsize=(15,10))
plt.imshow(wc)
plt.axis('off')# x,y좌표 숨김
plt.show()

# %% [markdown]
# ##### 글자체 변경
# - 경기천년체 'https://www.gg.go.kr/contents/contents.do?ciIdx=679&menuId=2457'

# %%
# 폰트 경로 변경
if platform.system() =='Windows':
    fontPath = 'C:/Windows/Fonts/경기천년제목_Bold.ttf'
elif platform.system() == 'Darwin': #macos
    fontPath = '/Users/$USER/Library/Fonts/AppleGothic.ttf'

# %%
import numpy as np
from PIL import Image, ImageOps

# %%
#워드 클라우드 다시
tagsLast = dict(tagFilterCounts.most_common(50))

mask = np.array(Image.open('./data/cloud.png'))
mask[mask.sum(axis=2) == 0] = 255 # 마스크이미지를 여백이 255가 되도록 변환

wc= WordCloud(font_path=fontPath, colormap='inferno', mask=mask,
              relative_scaling=0.4, width=1000, height=600,
              background_color='white', max_words=100).generate_from_frequencies(tagsLast)
plt.figure(figsize=(15,10))
plt.imshow(wc)
plt.axis('off')# x,y좌표 숨김
plt.savefig('./data/제주맛집_워드클라우드.png') # 이미지 파일 저장
plt.show()

# %% [markdown]
# #### 지도 시각화
# - Filium 사용
#
# ##### 주소에 대한 위경도 값 가져오기
# - 카카오 검색 API 사용
